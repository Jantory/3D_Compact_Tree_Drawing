# %%
from sage.plot.plot3d.shapes import *
t0 = (3.5,3.5,3.5)
GF = ColorCube([3.5, 3.5, 3.5], ['DodgerBlue','DodgerBlue','DodgerBlue'], opacity=0.1).translate(t0)
GF += cube(size = 7, color=['red', 'blue', 'green'], frame=False, frame_thickness=0.5,frame_color='dodgerblue', opacity=0).translate(t0)
#GF += Sphere(.05, color='grey') #comment
tf_root = (7 , 4 , 4)
tf_emp = (7 , 3 , 3)
GF += Sphere(.25, color='blue').translate(tf_root)
GF += Sphere(.25, color='lightblue').translate(tf_emp)
GF += line3d([(0,0,0), (0,0,7)], color = 'dodgerblue').translate(7, 3.5, 0)
GF += line3d([(0,0,0), (0,7,0)], color = 'dodgerblue').translate(7, 0, 3.5)
####GF = GF.rotateZ(-pi/2.1)
GF = GF.rotateZ(-pi/1.9).rotateX(-pi/15).rotateY(pi/15)
GF.show(frame=False)
# Out:
# Graphics3d Object

# %%
GG = ColorCube([3.5, 3.5, 3.5], ['orange','orange','orange'], opacity=0.1).translate(t0)
GG += cube(size = 7, color=['red', 'blue', 'green'], frame=False, frame_thickness=1,frame_color='orange', opacity=0).translate(t0)
#GG += Sphere(.05, color='grey') #comment
tf_root = (0 , 4 , 3)
tf_emp = (7 , 7 , 7)
GG += Sphere(.25, color='peru').translate(tf_root)
GG += Sphere(.25, color='wheat').translate(tf_emp)
GG += line3d([(0,0,0), (0,0,7)], color='orange').translate(0, 3.5, 0)
GG += line3d([(0,0,0), (0,7,0)], color='orange').translate(0, 0, 3.5)
GG = GG.rotateZ(-pi/1.9).rotateX(-pi/15).rotateY(pi/15)
#GG = GG.rotateZ(-pi/2.1)
GG.show(frame=False, viewer = 'threejs')
# Out:
# Graphics3d Object

# %%
GH = ColorCube([3.5, 3.5, 3.5], ['red','red','red'], opacity=0.075).translate(t0)
GH += cube(size = 7, color=['red', 'blue', 'green'], frame=False, frame_thickness=1,frame_color='tomato', opacity=0).translate(t0)
#GH += Sphere(.05, color='grey') #comment
tf_root = (0 , 4 , 3)
tf_emp = (0 , 0 , 7)
GH += Sphere(.25, color='red').translate(tf_root)
GH += Sphere(.25, color='lightpink').translate(tf_emp)
GH += line3d([(0,0,0), (0,0,7)], color='tomato').translate(0, 3.5, 0)
GH += line3d([(0,0,0), (0,7,0)], color='tomato').translate(0, 0, 3.5)
####GH = GH.rotateZ(-pi/2.1)
GH = GH.rotateZ(-pi/1.9).rotateX(-pi/15).rotateY(pi/15)
GH.show(aspect_ratio=[1,1,1], orientation=(0,0,0,0))
# Out:
# Graphics3d Object

# %%
#F recurse
F = GF + GF.translate(0, -8, 0) + GH.translate(8, 0, 0) + GG.translate(8, -8, 0)
F += GF.translate(0, 0, 8) + GF.translate(0, -8, 8) + GG.rotateX(pi).translate(0, 7, 7).translate(8, 0, 8) + GH.rotateX(pi).translate(0, 7, 7).translate(8, -8, 8)
#F += Sphere(1, color='black')
F += LineSegment((7,3,3), (8,4,3), thickness=3, color='grey')
F += LineSegment((7,3,3), (7,4,4), thickness=3, color='grey')
F += LineSegment((7,3,11), (8,3,12), thickness=3, color='grey')
F += LineSegment((7,3,11), (7,4,12), thickness=3, color='grey')
F += LineSegment((7,-5,3), (8,-4,3), thickness=3, color='grey')
F += LineSegment((7,-5,3), (7,-4,4), thickness=3, color='grey')
F += LineSegment((7,-5,11), (8,-5,12), thickness=3, color='grey')
F += LineSegment((7,-5,11), (7,-4,12), thickness=3, color='grey')
F += LineSegment((8,0,7), (7,3,3), thickness=3, color='slategrey')
F += LineSegment((8,0,7), (7,3,11), thickness=3, color='slategrey')
F += LineSegment((8,-1,8), (7,-5,3), thickness=3, color='slategrey')
F += LineSegment((8,-1,8), (7,-5,11), thickness=3, color='slategrey')
F += LineSegment((8,-1,8), (15,0,8), thickness=3, color='black')
F += LineSegment((8,0,7), (15,0,8), thickness=3, color='black')
#F = F.rotateZ(-pi/3.25)
#.rotateX(pi/50)
F = F.rotateZ(-pi/1.9).rotateX(-pi/15).rotateY(pi/15)
F.show(aspect_ratio=(1,1,1))
# Out:
# Graphics3d Object

# %%
#G recurse
G = GF + GF.translate(0, -8, 0) + GH.translate(8, 0, 0) + GG.translate(8, -8, 0)
G += GH.rotateZ(pi).translate(7, 7, 0).rotateX(pi).translate(0, 7, 7).translate(0, 0, 8) + GG.rotateZ(pi).translate(7, 7, 0).translate(0, -8, 8) + GF.rotateZ(pi).translate(7, 7, 0).translate(8, 0, 8) + GF.rotateZ(pi).translate(7, 7, 0).translate(8, -8, 8)
#G += Sphere(1, color='black')
G += LineSegment((7,3,3), (8,4,3), thickness=3, color='grey')
G += LineSegment((7,3,3), (7,4,4), thickness=3, color='grey')
G += LineSegment((8,4,11), (7,4,12), thickness=3, color='grey')
G += LineSegment((8,4,11), (8,3,12), thickness=3, color='grey')
G += LineSegment((7,-5,3), (8,-4,3), thickness=3, color='grey')
G += LineSegment((7,-5,3), (7,-4,4), thickness=3, color='grey')
G += LineSegment((8,-4,11), (8,-5,12), thickness=3, color='grey')
G += LineSegment((8,-4,11), (7,-5,11), thickness=3, color='grey')
G += LineSegment((8,0,7), (7,3,3), thickness=3, color='slategrey')
G += LineSegment((8,0,7), (7,-5,3), thickness=3, color='slategrey')
G += LineSegment((7,0,8), (8,-4,11), thickness=3, color='slategrey')
G += LineSegment((7,0,8), (8,4,11), thickness=3, color='slategrey')
G += LineSegment((7,0,8), (15,-1,7), thickness=3, color='black')
G += LineSegment((8,0,7), (15,-1,7), thickness=3, color='black')
G = G.rotateZ(pi).rotateZ(-pi/1.9).rotateX(-pi/15).rotateY(pi/15)
G.show(aspect_ratio=(1,1,1))
# Out:
# Graphics3d Object

# %%
#H recurse
H = GF + GF.translate(0, -8, 0) + GH.translate(8, 0, 0) + GG.translate(8, -8, 0)
H += GF.translate(0, 0, 8) + GF.translate(0, -8, 8) + GG.translate(8, 0, 8) + GH.rotateX(pi).translate(0, 7, 7).translate(8, -8, 8)
H += LineSegment((7,3,3), (8,4,3), thickness=3, color='grey')
H += LineSegment((7,3,3), (7,4,4), thickness=3, color='grey')
H += LineSegment((7,3,11), (7,4,12), thickness=3, color='grey')
H += LineSegment((7,3,11), (8,4,11), thickness=3, color='grey')
H += LineSegment((7,-5,3), (8,-4,3), thickness=3, color='grey')
H += LineSegment((7,-5,3), (7,-4,4), thickness=3, color='grey')
H += LineSegment((7,-5,11), (8,-5,12), thickness=3, color='grey')
H += LineSegment((7,-5,11), (7,-4,12), thickness=3, color='grey')
H += LineSegment((8,0,7), (7,3,3), thickness=3, color='slategrey')
H += LineSegment((8,0,7), (7,3,11), thickness=3, color='slategrey')
H += LineSegment((8,-1,8), (7,-5,3), thickness=3, color='slategrey')
H += LineSegment((8,-1,8), (7,-5,11), thickness=3, color='slategrey')
H += LineSegment((8,-1,8), (15,-1,7), thickness=3, color='black')
H += LineSegment((8,0,7), (15,-1,7), thickness=3, color='black')
H = H.rotateZ(pi).rotateZ(-pi/1.9).rotateX(-pi/15).rotateY(pi/15)
H.show(aspect_ratio=(1,1,1))
# Out:
# Graphics3d Object

# %%
sorted(colors)
# Out:
# ['aliceblue',
#  'antiquewhite',
#  'aqua',
#  'aquamarine',
#  'automatic',
#  'azure',
#  'beige',
#  'bisque',
#  'black',
#  'blanchedalmond',
#  'blue',
#  'blueviolet',
#  'brown',
#  'burlywood',
#  'cadetblue',
#  'chartreuse',
#  'chocolate',
#  'coral',
#  'cornflowerblue',
#  'cornsilk',
#  'crimson',
#  'cyan',
#  'darkblue',
#  'darkcyan',
#  'darkgoldenrod',
#  'darkgray',
#  'darkgreen',
#  'darkgrey',
#  'darkkhaki',
#  'darkmagenta',
#  'darkolivegreen',
#  'darkorange',
#  'darkorchid',
#  'darkred',
#  'darksalmon',
#  'darkseagreen',
#  'darkslateblue',
#  'darkslategray',
#  'darkslategrey',
#  'darkturquoise',
#  'darkviolet',
#  'deeppink',
#  'deepskyblue',
#  'dimgray',
#  'dimgrey',
#  'dodgerblue',
#  'firebrick',
#  'floralwhite',
#  'forestgreen',
#  'fuchsia',
#  'gainsboro',
#  'ghostwhite',
#  'gold',
#  'goldenrod',
#  'gray',
#  'green',
#  'greenyellow',
#  'grey',
#  'honeydew',
#  'hotpink',
#  'indianred',
#  'indigo',
#  'ivory',
#  'khaki',
# ...

# %%
var('k')
value = 8
#F 
f_root_x = 2*2^((k-2)/3) - 1
f_root_y = 2^((k-2)/3) + 1 - 1
f_root_z = 2^((k-2)/3) + 1 - 1
f_emp_x = 2*2^((k-2)/3) - 1
f_emp_y = 2^((k-2)/3) - 1
f_emp_z = 2^((k-2)/3) - 1
print(f_root_x.subs(k=value), ",", f_root_y.subs(k=value), ",", f_root_z.subs(k=value))
print(f_emp_x.subs(k=value), ",", f_emp_y.subs(k=value), ",", f_emp_z.subs(k=value))

# %%
#G
g_root_x = 1 - 1
g_root_y = 2^((k-2)/3) + 1 - 1
g_root_z = 2^((k-2)/3) - 1
g_emp_x = 2*2^((k-2)/3) - 1
g_emp_y = 2*2^((k-2)/3) - 1
g_emp_z = 2*2^((k-2)/3) - 1
print(g_root_x.subs(k=value), ",", g_root_y.subs(k=value), ",", g_root_z.subs(k=value))
print(g_emp_x.subs(k=value), ",", g_emp_y.subs(k=value), ",", g_emp_z.subs(k=value))
# Out:
# 1 , 5 , 4
# 8 , 8 , 8

# %%
#H
h_root_x = 1 - 1
h_root_y = 2^((k-2)/3) + 1 - 1
h_root_z = 2^((k-2)/3) - 1
h_emp_x = 1 - 1
h_emp_y = 1 - 1
h_emp_z = 2*2^((k-2)/3) - 1
print(h_root_x.subs(k=value), ",", h_root_y.subs(k=value), ",", h_root_z.subs(k=value))
print(h_emp_x.subs(k=value), ",", h_emp_y.subs(k=value), ",", h_emp_z.subs(k=value))
# Out:
# 1 , 5 , 4
# 1 , 1 , 8
